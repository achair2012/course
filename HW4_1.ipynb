# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_by_population_(United_Nations)')

# %%
df_lot=df[2]
df_lot.head()
# Out:
#       0                1                        2                        3  \
# 0  Rank  Country or area  UN continentalregion[2]  UN statisticalregion[2]
# 1     —            World                        —                        —
# 2     1         China[a]                     Asia             Eastern Asia
# 3     2            India                     Asia            Southern Asia
# 4     3    United States                 Americas         Northern America
#
#                             4                           5       6
# 0  Population(1 July 2016)[3]  Population(1 July 2017)[3]  Change
# 1                  7466964280                  7550262101   +1.1%
# 2                  1403500365                  1409517397   +0.4%
# 3                  1324171354                  1339180127   +1.1%
# 4                   322179605                   324459463   +0.7%

# %%
df_50=df_lot[:52]

# %%
df_50
# Out:
#        0                                 1                        2  \
# 0   Rank                   Country or area  UN continentalregion[2]
# 1      —                             World                        —
# 2      1                          China[a]                     Asia
# 3      2                             India                     Asia
# 4      3                     United States                 Americas
# 5      4                         Indonesia                     Asia
# 6      5                            Brazil                 Americas
# 7      6                          Pakistan                     Asia
# 8      7                           Nigeria                   Africa
# 9      8                        Bangladesh                     Asia
# 10     9                            Russia                   Europe
# 11    10                            Mexico                 Americas
# 12    11                             Japan                     Asia
# ...

# %%
colnames = df_50.loc[0].values

# %%
colnames
# Out:
# array(['Rank', 'Country or area', 'UN continentalregion[2]',
#        'UN statisticalregion[2]', 'Population(1 July 2016)[3]',
#        'Population(1 July 2017)[3]', 'Change'], dtype=object)

# %%
df_50.columns = colnames

# %%
Asia = df_50[(df_50['UN continentalregion[2]']=='Asia')]

# %%
Asia
# Out:
#    Rank Country or area UN continentalregion[2] UN statisticalregion[2]  \
# 2     1        China[a]                    Asia            Eastern Asia
# 3     2           India                    Asia           Southern Asia
# 5     4       Indonesia                    Asia      South-eastern Asia
# 7     6        Pakistan                    Asia           Southern Asia
# 9     8      Bangladesh                    Asia           Southern Asia
# 12   11           Japan                    Asia            Eastern Asia
# 14   13     Philippines                    Asia      South-eastern Asia
# 16   15         Vietnam                    Asia      South-eastern Asia
# 19   18            Iran                    Asia           Southern Asia
# 20   19          Turkey                    Asia            Western Asia
# 21   20        Thailand                    Asia      South-eastern Asia
# 27   26         Myanmar                    Asia      South-eastern Asia
# ...
